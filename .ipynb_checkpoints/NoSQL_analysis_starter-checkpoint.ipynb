# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 2: Jupyter Notebook Set Up¶

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %% [markdown]
# ### - Create an instance of MongoClient

# %%
mongo = MongoClient(port=27017)

# %% [markdown]
# ### - assign the uk_food database to a variable name

# %%
db = mongo['uk_food']

# %% [markdown]
# ### - review the collections in our database

# %%
print(db.list_collection_names())
# Out:
# ['establishments']

# %% [markdown]
# ### - assign the collection to a variable

# %%
establishments = db['establishments']

# %% [markdown]
# ### - print thenumber of estabalishments in the collection
# - 'print("Number of occuments in 'establishments': ", establishments.count_documents({}))'

# %%
print("Number of occuments in 'establishments': ", establishments.count_documents({}))
# Out:
# Number of occuments in 'establishments':  38786

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %% [markdown]
# ### - find the establishments with a hygiene score of 20

# %%
query = {"scores.Hygiene": 20}
hygiene_results = establishments.find(query)

# %% [markdown]
# ### - use count_documents to display the number of documents in the result

# %%
document_count = establishments.count_documents(query)
print(f"Number of establishments with hygiene score of 20: {document_count}")
# Out:
# Number of establishments with hygiene score of 20: 41

# %% [markdown]
# ### - Display the first document in the results using pprint

# %%
print("First document returned: ")
pprint(hygiene_results[0])
# Out:
# First document returned:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67a11a6be95bf9578dd9ba13'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
# ...

# %% [markdown]
# ### - Convert the result to a Pandas DataFrame
# - 'hygiene_df = pd.DataFrame(list(hygiene_results))'

# %%
hygiene_df = pd.DataFrame(list(hygiene_results))

# %% [markdown]
# ### - Display the number of rows in the DataFrame
# - ''print(f"Number of rows i the 'results_df' dataframe: {results_df.shape(10)[0]}")'

# %%
print(f"Number of rows in the 'hygiene_df' dataframe: {hygiene_df.shape[0]}")
# Out:
# Number of rows in the 'hygiene_df' dataframe: 41

# %% [markdown]
# ### - Display the first 10 rows of the DataFrame
# - 'hygiene_df.head(10)'

# %%
hygiene_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  67a11a6be95bf9578dd9ba13   110681                  0
# 1  67a11a6be95bf9578dd9bd94   612039                  0
# 2  67a11a6be95bf9578dd9c09e   730933                  0
# 3  67a11a6be95bf9578dd9c28c   172735                  0
# 4  67a11a6be95bf9578dd9c29b   172953                  0
# 5  67a11a6be95bf9578dd9cc3a   512854                  0
# 6  67a11a6be95bf9578dd9ce5b  1537089                  0
# 7  67a11a6be95bf9578dd9e386   155648                  0
# 8  67a11a6be95bf9578dd9e7ca  1012883                  0
# 9  67a11a6be95bf9578dd9efdc   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %%
hygiene_df.columns
# Out:
# Index(['_id', 'FHRSID', 'ChangesByServerID', 'LocalAuthorityBusinessID',
#        'BusinessName', 'BusinessType', 'BusinessTypeID', 'AddressLine1',
#        'AddressLine2', 'AddressLine3', 'AddressLine4', 'PostCode', 'Phone',
#        'RatingValue', 'RatingKey', 'RatingDate', 'LocalAuthorityCode',
#        'LocalAuthorityName', 'LocalAuthorityWebSite',
#        'LocalAuthorityEmailAddress', 'scores', 'SchemeType', 'geocode',
#        'RightToReply', 'Distance', 'NewRatingPending', 'meta', 'links'],
#       dtype='object')

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %% [markdown]
# ### Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
# ### NOTE: Greater London contains 32 bouroughs, many do not have 'London' in their name (such as 'Westminster' and 'Chelsea').
# ### Here we only identify establishments in the City of London, one of the 32 bouroughs in greater London,
# - query_2 ={'LocalAuthorityName':{'$regex':  "London"}, }
# - 'results_2 = establishments.find(query)'

# %%
query_2 ={'LocalAuthorityName':{'$regex':  "London"}, 'RatingValue': {'$gte': 4}}
results_2 = establishments.find(query_2)
pprint(results_2[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67a11a6be95bf9578dd9d42e'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %% [markdown]
# # Use count_documents to display the number of documents in the result
# - 'document_count_2 = establishments.count_documents(query)'

# %%
document_count_2 = establishments.count_documents(query_2)
print(f"Number of establishments with LocalAuthorityName of London and 'Raiting Value' >= 4: {establishments.count_documents(query_2)}")
# Out:
# Number of establishments with LocalAuthorityName of London and 'Raiting Value' >= 4: 33

# %% [markdown]
# # Display the first document in the results using pprint
# - 'print("First document returned: ")'
# - 'pprint(results[0])'

# %%
print("First document returned: ")
pprint(results_2[0])
# Out:
# First document returned:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67a11a6be95bf9578dd9d42e'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %% [markdown]
# ### - Convert the result to a Pandas DataFrame

# %%
london_rated_4_df = pd.DataFrame(list(results_2))

# %% [markdown]
# ### - Display the number of rows in the DataFrame

# %%
print(f"Number of rows in the 'hygiene_df' dataframe: {london_rated_4_df.shape[0]}")

# %% [markdown]
# ### - Display the first 10 rows of the DataFrame

# %%
london_rated_4_df.head(10)
# Out:
# Number of rows in the 'hygiene_df' dataframe: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  67a11a6be95bf9578dd9d42e   621707                  0
# 1  67a11a6be95bf9578dd9d754  1130836                  0
# 2  67a11a6be95bf9578dd9e2a1   293783                  0
# 3  67a11a6be95bf9578dd9f0a1  1315095                  0
# 4  67a11a6be95bf9578dd9f0a2   294474                  0
# 5  67a11a6be95bf9578dd9f7aa   294900                  0
# 6  67a11a6be95bf9578dda18b8   293756                  0
# 7  67a11a6be95bf9578dda1c7f   878523                  0
# 8  67a11a6be95bf9578dda1c99   293772                  0
# 9  67a11a6be95bf9578dda1c9a   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, <<nearest to the new restaurant added, "Penang Flavours">>? NOTE: 'Penang Flavors' data did not iinclude longitude and latitude (I added some arbitray numbers so the fields would not be enpty).

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude =
longitude =

query =
sort =
limit =

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
